# %%
# ===============================
# Step 1: Import required libraries
# ===============================
import pandas as pd               # for data handling
import seaborn as sns             # for visualization
import matplotlib.pyplot as plt   # for plotting graphs

# %%
# ===============================
# Step 2: Load the dataset
# ===============================
# Replace "iris.csv" with the correct path if your file is in another folder
df = pd.read_csv('../data/iris.csv')

# Show first 5 rows of the dataset
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# ===============================
# Step 3: Check basic dataset information
# ===============================
print("Shape of dataset (rows, columns):", df.shape)   # total rows and columns
print("\nColumn names:", df.columns.tolist())          # list of columns
print("\nData types of each column:\n", df.dtypes)     # data type of each column
# Out:
# Shape of dataset (rows, columns): (150, 6)
#
# Column names: ['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species']
#
# Data types of each column:
#  Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
# ===============================
# Step 4: Check data quality
# ==============================
# Missing values in each column
print("Missing values:\n", df.isnull().sum())

# Number of duplicate rows
print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Missing values:
#  Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
#
# Duplicate rows: 0

# %%
# ===============================
# Step 5: Summary statistics
# ===============================
# Mean of numeric columns
print("\nMean values:\n", df.mean(numeric_only=True))

# Median of numeric columns
print("\nMedian values:\n", df.median(numeric_only=True))

# Mode (most frequent value) of each column
print("\nMode values:\n", df.mode().iloc[0])

# Full statistical summary (count, mean, std, min, max, quartiles)
print("\nDescribe dataset:\n", df.describe())
# Out:
# Mean values:
#  Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64
#
# Median values:
#  Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64
#
# Mode values:
#  Id                         1
# SepalLengthCm            5.0
# SepalWidthCm             3.0
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object
#
# Describe dataset:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# ...

# %%
# ===============================
# Step 6: Group statistics (by species)
# ===============================
# Make sure your dataset has a "species" column
df.groupby("Species").mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
# ===============================
# Step 7: Visualizations
# ===============================

# 1. Histogram of all features
df.hist(figsize=(10, 8))
plt.suptitle("Histograms of Iris Features", fontsize=14)
plt.show()

# %%
# 2. Boxplot (petal length by species)
plt.figure(figsize=(6,4))
sns.boxplot(x="Species", y="PetalLengthCm", data=df)
plt.title("Petal Length by Species")
plt.show()

# %%
# 3. Scatterplot (Sepal Length vs Sepal Width, colored by Species)
plt.figure(figsize=(6,4))
sns.scatterplot(x="SepalLengthCm", y="SepalWidthCm", hue="Species", data=df)
plt.title("Sepal Length vs Sepal Width")
plt.show()

# %%
# 4. Pairplot (all features compared)
sns.pairplot(df, hue="Species")
plt.suptitle("Pairplot of Iris Dataset", y=1.02)
plt.show()

# %%
# 5. Correlation heatmap
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# ===============================
# Step 8: Insights (Simple Observations)
# ===============================
print("🔹 Insights from the Iris Dataset:")
print("- Setosa species has much smaller petals compared to the other two.")
print("- Virginica usually has the longest petals and sepals.")
print("- Versicolor is in between Setosa and Virginica in size.")
print("- Petal length and petal width are strongly correlated.")
print("- Sepal width varies less between species.")
# Out:
# 🔹 Insights from the Iris Dataset:
# - Setosa species has much smaller petals compared to the other two.
# - Virginica usually has the longest petals and sepals.
# - Versicolor is in between Setosa and Virginica in size.
# - Petal length and petal width are strongly correlated.
# - Sepal width varies less between species.
